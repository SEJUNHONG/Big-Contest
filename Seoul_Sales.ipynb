# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
seoul_sales=pd.read_csv("서울시 우리마을가게 상권분석서비스(상권-추정매출)_2019.csv", engine='python')
seoul_sales_2019=pd.DataFrame(seoul_sales)
seoul_sales_2019
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2019         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1          2019         4        U       관광특구  1001496  강남 마이스 관광특구  CS300035
# 2          2019         4        U       관광특구  1001496  강남 마이스 관광특구  CS300032
# 3          2019         4        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 4          2019         4        U       관광특구  1001496  강남 마이스 관광특구  CS300028
# ...         ...       ...      ...        ...      ...          ...       ...
# 177225     2019         1        A       골목상권  1000001          계동길  CS100005
# 177226     2019         1        A       골목상권  1000001          계동길  CS100004
# 177227     2019         1        A       골목상권  1000001          계동길  CS100003
# 177228     2019         1        A       골목상권  1000001          계동길  CS100002
# 177229     2019         1        A       골목상권  1000001          계동길  CS100001
#
# ...

# %%
seoul_sales_2019.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '당월_매출_금액', '당월_매출_건수', '주중_매출_비율',
#        '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
#        '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
#        '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
#        '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
#        '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
#        '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
# ...

# %%
business_area=seoul_sales_2019['상권_코드_명'].unique()
print(business_area)
print(len(seoul_sales_2019['상권_코드_명'].unique()))
# Out:
# ['강남 마이스 관광특구' '잠실 관광특구' '종로·청계 관광특구' ... '계동길' '신설종합시장' '대학14길']
# 1489

# %%
category=seoul_sales_2019['서비스_업종_코드_명'].unique()
print(category)
print(len(category))
# Out:
# ['전자상거래업' '인테리어' '가전제품' '가구' '화초' '섬유제품' '완구' '운동/경기용품' '화장품' '문구' '의약품'
#  '시계및귀금속' '안경' '가방' '신발' '일반의류' '반찬가게' '핸드폰' '컴퓨터및주변장치판매' '편의점' '슈퍼마켓'
#  '피부관리실' '네일숍' '미용실' '스포츠클럽' '치과의원' '일반의원' '커피-음료' '분식전문점' '패스트푸드점' '제과점'
#  '양식음식점' '일식음식점' '중식음식점' '한식음식점' '서적' '의료기기' '육류판매' '노래방' '고시원' '여관' '세탁소'
#  '자동차수리' 'PC방' '골프연습장' '당구장' '한의원' '스포츠 강습' '호프-간이주점' '치킨전문점' '조명용품' '철물점'
#  '애완동물' '청과상' '수산물판매' '미곡판매' '가전제품수리' '예술학원' '외국어학원' '일반교습학원' '자동차미용'
#  '부동산중개업' '자전거 및 기타운송장비' '유아의류' '한복점' '볼링장' '회계사사무소' '기타법무서비스' '컴퓨터학원'
#  '주류도매' '세무사사무소' '법무사사무소' '변리사사무소' '변호사사무소' '동물병원']
# 75

# %%
category_name=['가전제품', '가구', '화초', '섬유제품', '완구', '운동/경기용품', '화장품', '문구', '시계및귀금속',
               '안경', '가방', '신발', '일반의류', '반찬가게', '컴퓨터및주변장치판매', '편의점', '슈퍼마켓', '커피-음료',
               '분식전문점', '패스트푸드점', '제과점', '양식음식점', '일식음식점', '중식음식점', '한식음식점', '서적',
               '육류판매', '호프-간이주점', '치킨전문점', '조명용품', '철물점', '청과상', '수산물판매', '미곡판매',
               '유아의류', '한복점', '주류도매']
print(len(category_name))
# Out:
# 37

# %%
E=seoul_sales_2019.groupby(['상권_코드_명', '서비스_업종_코드_명', '기준_분기_코드'])
category_seoul=E.sum()
category_seoul
# Out:
#                               기준_년_코드    상권_코드      당월_매출_금액  당월_매출_건수  \
# 상권_코드_명 서비스_업종_코드_명 기준_분기_코드
# 가락시장    미곡판매        4            2019  1001060   17784890556    280217
#         반찬가게        1            2019  1001060   21668463261    354392
#                     2            2019  1001060   17841577104    198941
#                     3            2019  1001060   17462095928    209922
#                     4            2019  1001060  242036013085   4487383
# ...                               ...      ...           ...       ...
# 흑석시장    호프-간이주점     3            2019  1001448     228207020      4522
#                     4            2019  1001448     403207421      8681
#         회계사사무소      1            2019  1001448      43460022       130
#                     2            2019  1001448      28615704       108
#                     3            2019  1001448      21210600       151
#
#                               주중_매출_비율  주말_매출_비율  월요일_매출_비율  화요일_매출_비율  \
# ...

# %%
seoul_sales_2019_1=seoul_sales_2019[seoul_sales_2019['기준_분기_코드']==1]
E_1=seoul_sales_2019_1.groupby(['상권_코드_명', '서비스_업종_코드_명'])
category_seoul_1=E_1.sum()
#category_seoul_1

# %%
seoul_sales_2019_2=seoul_sales_2019[seoul_sales_2019['기준_분기_코드']==2]
E_2=seoul_sales_2019_2.groupby(['상권_코드_명', '서비스_업종_코드_명'])
category_seoul_2=E_2.sum()
#category_seoul_2

# %%
seoul_sales_2019_3=seoul_sales_2019[seoul_sales_2019['기준_분기_코드']==3]
E_3=seoul_sales_2019_3.groupby(['상권_코드_명', '서비스_업종_코드_명'])
category_seoul_3=E_3.sum()
#category_seoul_3

# %%
seoul_sales_2019_4=seoul_sales_2019[seoul_sales_2019['기준_분기_코드']==4]
E_4=seoul_sales_2019_4.groupby(['상권_코드_명', '서비스_업종_코드_명'])
category_seoul_4=E_4.sum()
#category_seoul_4

# %%
#for i in range(len(business_area)):
    for j in range(len(category_name)):
        try:
            plt.rcParams['figure.figsize']=[5,5]
            #area_2019_1=category_seoul_1.loc[business_area[i]].loc[category_name[j]]
            #area_2019_2=category_seoul_2.loc[business_area[i]].loc[category_name[j]]
            #area_2019_3=category_seoul_3.loc[business_area[i]].loc[category_name[j]]
            #area_2019_4=category_seoul_4.loc[business_area[i]].loc[category_name[j]]
            #print(business_area[i], category_name[j])
            #budget_data=[area_2019_1['당월_매출_금액'], area_2019_2['당월_매출_금액'], area_2019_3['당월_매출_금액'], area_2019_4['당월_매출_금액']]
            #budget_category=['2019_1/4 USE_AMOUNT', '2019_2/4 USE_AMOUNT', '2019_3/4 USE_AMOUNT', '2019_4/4 USE_AMOUNT']
            colors=['red', 'yellow' , 'green', 'blue']
            #plt.pie(budget_data, labels=budget_category, autopct='%0.1f%%', colors=colors)
            #plt.show()
            plt.close()
        except:
            pass
# Out:
#   File "<ipython-input-12-d8cf5d877aa8>", line 2
#     for j in range(len(category_name)):
#     ^
# IndentationError: unexpected indent

# %%
#for i in range(len(business_area)):
    for j in range(len(category_name)):
        try:
            plt.rcParams['figure.figsize']=[5,5]
            #area_2019_1=category_seoul_1.loc[business_area[i]].loc[category_name[j]]
            #area_2019_2=category_seoul_2.loc[business_area[i]].loc[category_name[j]]
            #area_2019_3=category_seoul_3.loc[business_area[i]].loc[category_name[j]]
            #area_2019_4=category_seoul_4.loc[business_area[i]].loc[category_name[j]]
            #print(business_area[i], category_name[j])
            #budget_data=[area_2019_1['당월_매출_건수'], area_2019_2['당월_매출_건수'], area_2019_3['당월_매출_건수'], area_2019_4['당월_매출_건수']]
            #budget_category=['2019_1/4 USE_COUNT', '2019_2/4 USE_COUNT', '2019_3/4 USE_COUNT', '2019_4/4 USE_COUNT']
            colors=['pink', 'orange' , 'lightgreen', 'lightskyblue']
            #plt.pie(budget_data, labels=budget_category, autopct='%0.1f%%', colors=colors)
            #plt.show()
            plt.close()
        except:
            pass
